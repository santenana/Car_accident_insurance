# %%
import pandas as pd
import numpy as np  
import cv2 as cv
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from imagen import imagen_detect
from ultralytics import YOLO
import torch
import matplotlib.pyplot as plt
path = '/home/santenana/Proyectos/02_ObjectDetection/test4.jpeg'
model_path = "/home/santenana/Proyectos/02_ObjectDetection/best.pt"
model = YOLO(model_path)
img,label = imagen_detect(path,model)
plt.imshow(img)
plt.show()
print(label[0])
# Out:
# /home/santenana/miniconda3/envs/Detection/lib/python3.8/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# image 1/1 /home/santenana/Proyectos/02_ObjectDetection/test4.jpeg: 416x640 1 moderate, 78.8ms
# Speed: 2.5ms preprocess, 78.8ms inference, 59.3ms postprocess per image at shape (1, 3, 416, 640)
# moderate

# %%
from video_detect import Video
best_model = YOLO("/home/santenana/Proyectos/02_ObjectDetection/runs/detect/train12/weights/best.pt")
path_video = '/home/santenana/Proyectos/02_ObjectDetection/video_accidente2.mp4'
label,prob = Video(path_video,best_model)
# Out:
# 0: 384x640 1 moderate, 78.1ms
# Speed: 0.8ms preprocess, 78.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 moderate, 5.6ms
# Speed: 1.6ms preprocess, 5.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 moderate, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 moderate, 5.1ms
# Speed: 1.5ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 moderate, 10.0ms
# Speed: 1.1ms preprocess, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 moderate, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 moderate, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 moderate, 5.4ms
# ...

# %%
print(label)
print(prob)
# Out:
# moderate
# 1.0
